# %%
spark

# %%
df=spark.read.csv("/Volumes/dev/naval/raw/Spotify_Songs.csv",header=True, inferSchema=True)

# %%
df.display()
df.count()
df.printSchema()

# %%
df1 = df.withColumn("ingestion_date",current_date())

# %%
df1.display()

# %%
df1.write.mode("overwrite").saveAsTable("dev.srinu.spotify_songs")
#df1.write.mode("overwrite").format("parquet").saveAsTable("dev.srinu.spotify_songs")

# %%
# %sql
describe extended dev.srinu.spotify_songs

# %%
# %sql
select * from dev.srinu.spotify_songs;
