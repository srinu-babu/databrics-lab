# %%
spark

# %%
df=spark.read.csv("/Volumes/dev/naval/raw/Spotify_Songs.csv",header=True, inferSchema=True)

# %%
df.display()
df.count()
df.printSchema()

# %%
from pyspark.sql.functions import *
#df.select("*").display()
df.select(col("song_id").alias("sondid")).display()

# %%
df.filter(col("song_id") == 1).display()

# %%
df.withColumnRenamed("song_id","songid").display()

# %%
df.withColumn("ingestion_date",current_date()).display()
