# %%
spark

# %%
from pyspark.sql.functions import *

# %%
df=spark.read.csv("/Volumes/dev/naval/raw/1000_richest_people_in_the_world.csv",header=True)

# %%
df1 = df.withColumn("ingestion_date",current_date())

# %%
df1.display()

# %%
df2=df1.withColumnRenamed("Net Worth (in billions)","net_worth_in_billion")
df2.display()

# %%
df2.write.saveAsTable("dev.srinu.richest_people")

# %%
# %sql
describe extended dev.srinu.richest_people

# %%
# %sql
select * from dev.srinu.richest_people;
