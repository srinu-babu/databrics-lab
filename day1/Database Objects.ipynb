# %%
# %sql
use catalog dev;

# %%
# %sql
create schema dev.srinu;

# %%
# %sql
--create table dev.srinu.demo (id int, name string);
create table dev.srinu.employee (id int, name string);

# %% [markdown]
# ![](/Volumes/dev/srinu/volume-1/anydesk.dmg)

# %% [markdown]
# ![](/Volumes/dev/srinu/volume-1/anydesk.dmg)
