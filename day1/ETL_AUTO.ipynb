# %%
# %run "/Workspace/Users/work.srinu.in@gmail.com/day1/includes"

# %%
dbutils.widgets.text("catalog", "dev")
dbutils.widgets.text("schema", "srinu")
dbutils.widgets.text("table", "Spotify_Songs")
catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")
table = dbutils.widgets.get("table")

# %%
df = spark.read.csv(f"{input_path}{table}.csv", header=True,inferSchema=True)

# %%
df.display()

# %%
#ingestion column
df1=add_ingestion(df)
#saving to table
df1.write.mode("overwrite").saveAsTable(f"{catalog}.{schema}.{table}")
