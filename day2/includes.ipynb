# %%
# %sql
create schema if not exists dev.srinu_bronze;
create schema if not exists dev.srinu_silver;
create schema if not exists dev.srinu_gold;

# %%
# %python
input_path="/Volumes/dev/naval/raw"

# %% [markdown]
# The above location contains the below files
# account_info.json
#
# customer_prfile.json
#
# transactions.csv

# %%
spark
from pyspark.sql.functions import *
def add_ingestion(df):
    df1=df.withColumn("ingestion_date",current_date())
    return df1
