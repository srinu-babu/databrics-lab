# %%
# %sql
create table if not exists dev.srinu.atm_transactions(account_number int, amount float)

# %%
# %sql
describe history dev.srinu.atm_transactions;

# %%
# %sql
insert into dev.srinu.atm_transactions values(1, 1000.5)

# %%
# %sql
select * from dev.srinu.atm_transactions;

# %%
# %sql
describe extended dev.srinu.atm_transactions;

# %%
# %sql
describe detail dev.srinu.atm_transactions;

# %%
# %sql
insert into dev.srinu.atm_transactions values(2, 1001.5),(3, 1003.5)

# %%
# %sql
describe history dev.srinu.atm_transactions;

# %%
# %sql
delete from dev.srinu.atm_transactions where account_number = 2

# %%
# %sql
describe history dev.srinu.atm_transactions;

# %%
# %sql
update dev.srinu.atm_transactions set amount = 10000.55 where account_number = 3

# %%
# %sql
describe history dev.srinu.atm_transactions;

# %%
# %sql
select * from dev.srinu.atm_transactions;

# %%
# %sql
create table dev.srinu.sales_ext(id int) location 's3://jpmdatabricks/externaltable/srinu/sales'

# %%
# %sql
insert into dev.srinu.sales_ext values(1),(2)

# %%
# %sql
select * from dev.srinu.sales_ext;

# %%
# %sql
describe extended dev.srinu.sales_ext;

# %%
# %sql
create or replace view dev.srinu.richest_people_view as 
(select Industry, count(*) as count from dev.srinu.richest_people group by all)

# %%
# %sql
select * from dev.srinu.richest_people_view;

# %%
# %sql
use catalog dev;
show views in srinu;

# %%
# %sql
create or replace temp view richest_people_temp_view as 
(select Industry, count(*) as count from dev.srinu.richest_people group by all)

# %%
# %sql
use catalog dev;
show views in srinu;
