# %%
# %run "/Workspace/Users/work.srinu.in@gmail.com/day2/includes"

# %%
# %sql
create or replace table dev.srinu_bronze.transaction
as 
(SELECT *,current_timestamp() as ingestion_date FROM read_files(
    '/Volumes/dev/naval/raw/transactions.csv',
    format => 'csv'))

# %%
# %sql
select * from dev.srinu_bronze.transaction;

# %%
input_path

# %%
df=spark.read.json(f"{input_path}/account_info.json")
df.write.mode("overwrite").saveAsTable("dev.srinu_bronze.account_info")

# %%
# %sql
select * from dev.srinu_bronze.account_info;

# %%
df=spark.read.json(f"{input_path}/customer_prfile.json")
df.write.mode("overwrite").saveAsTable("dev.srinu_bronze.customer_profile")

# %%
# %sql
select * from dev.srinu_bronze.customer_profile;
