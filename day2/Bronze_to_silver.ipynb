# %%
# %run "/Workspace/Users/work.srinu.in@gmail.com/day2/includes"

# %%
df=spark.table("dev.srinu_bronze.transaction")
dffinal=df.dropDuplicates().drop("_rescued_data","ingestion_date").dropna()
dffinal.write.mode("overwrite").saveAsTable("dev.srinu_silver.transaction")

# %%
# %sql
select * from dev.srinu_silver.transaction;

# %%
# %python
df=spark.table("dev.srinu_bronze.account_info")
dffinal=df.dropDuplicates().dropna()
dffinal.write.mode("overwrite").saveAsTable("dev.srinu_silver.account_info")

# %%
# %sql
select * from dev.srinu_silver.account_info;

# %%
# %python
df=spark.table("dev.srinu_bronze.customer_profile")
dffinal=df.dropDuplicates().dropna()
dffinal.write.mode("overwrite").saveAsTable("dev.srinu_silver.customer_profile")

# %%
# %sql
select * from dev.srinu_silver.customer_profile;

# %%
# %sql
SELECT customer_id, SUM(amount) as total_amount, COUNT(*) as txn_count
FROM dev.srinu_silver.transaction
GROUP BY customer_id;

# %%
# %sql
SELECT t.transaction_id, t.amount, t.transaction_type, t.timestamp,
       c.name AS customer_name, c.email, a.account_type, a.account_balance
FROM dev.srinu_silver.transaction t
LEFT JOIN dev.srinu_silver.customer_profile c ON t.customer_id = c.customer_id
LEFT JOIN dev.srinu_silver.account_info a ON t.customer_id = a.customer_id
